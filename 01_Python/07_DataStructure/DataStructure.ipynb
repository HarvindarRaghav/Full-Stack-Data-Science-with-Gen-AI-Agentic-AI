# %% [markdown]
# # List

# %%
l = [] # Empty list

# %%
type(l)
# Out:
# list

# %%
l1 = [2, 10 ,'welcome',[3,5,6],2+8j]
l1
# Out:
# [2, 10, 'welcome', [3, 5, 6], (2+8j)]

# %%
l2 = [2, 10 ,'welcome',[3,5,6],2+8j]
print(id(l1))
print(id(l2))
# Out:
# 2492019662784
# 2491996865152

# %%
l1.extend(l2)

l1
# Out:
# [2, 10, 'welcome', [3, 5, 6], (2+8j), 2, 10, 'welcome', [3, 5, 6], (2+8j)]
