# %% [markdown]
# # Dist

# %%
mydist = {'key1':'value1','key2':'value2'}
mydist['key2']

# %%
youdisct = {'key1':'value1','key2':[0,1,2,3,4,8,6,7],'key3':34}
youdisct['key2'][5]

# %%
# my dictoniry example
d = {'key1':[0,1,2,3,4,5],'key2':['a','b','c','d']}
mylist = d['key2']
mylist[2].upper()

# %%
d.keys()
d.values()

# %%
#Tuple is just list only but immutable and use paranthesis instead bracket []
t =(1,2,3,4,5)
mylist =[1,1,2,2,3,3,4,5,6,6]
type(t)

# %%
type(mylist)
t1 =("one",1,1,1,1,2,3,"two")
t1.count(1)
t1.index(1)
