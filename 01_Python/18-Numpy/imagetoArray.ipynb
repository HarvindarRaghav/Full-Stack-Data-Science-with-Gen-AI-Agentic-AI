# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
#pip install pillow
# Out:
# Requirement already satisfied: pillow in c:\python311\lib\site-packages (12.3.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\dell\Full-Stack-Data-Science-with-Gen-AI-Agentic-AI\.venv\Scripts\python.exe

# %%
from PIL import Image

# %%
image = Image.open(r'C:\Users\dell\Full-Stack-Data-Science-with-Gen-AI-Agentic-AI\01_Python\18-Numpy\image.jpg')

# %%
display(image)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=165x166>

# %%
cropped = image.crop((100, 100, 500, 500))

display(cropped)
# Out:
# <PIL.Image.Image image mode=RGB size=400x400>

# %%
print(image.size)
print(image.mode)
# Out:
# (165, 166)
# RGB

# %% [markdown]
# ## 2. Check image size

# %%
print(image.size)
# Out:
# (165, 166)

# %% [markdown]
# ### Rotate image

# %%
rotated = image.rotate(90)

display(rotated)
# Out:
# <PIL.Image.Image image mode=RGB size=165x166>

# %%
image.rotate(45)
image.rotate(90)
image.rotate(180)
image.rotate(270)
# Out:
# <PIL.Image.Image image mode=RGB size=165x166>

# %% [markdown]
# ## Flip image horizontally

# %%
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=165x166>
