# %% [markdown]
# ### Numpy:- this is a python Library to Handle the 1D,2D,3D Array

# %%
name = 'ram'
age = 33
print(f'{name} is {age} year old')
# Out:
# ram is 33 year old

# %%
name = 'ram'
age = 33
print(f'{name} is {age} year old')
# Out:
# ram is 33 year old

# %%
print(f'{name} is {age} year old')
# Out:
# ram is 33 year old
