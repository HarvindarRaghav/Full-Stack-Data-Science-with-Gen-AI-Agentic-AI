# %% [markdown]
# Basics of Function

# %%
def greet():
    print("good morning")

greet()
# Out:
# Failed to start the Kernel.
#
# Unable to start Kernel '.venv (3.11.4) (Python 3.11.4)' due to a timeout waiting for the ports to get used.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
